# %% [markdown]
# # Machine learning methods on 3D data

# %% [raw]
# This notebook is to demostrate how to search a lession in a 3D breast image using machine learning methods.

# %%
import numpy as np
from matplotlib import pyplot as plt
import matplotlib as mpl
mpl.rc('figure', figsize=(11, 9))
mpl.__version__
# Out:
# '1.2.1'

# %%
d_x = 760
d_y = 195
d_z = 240
income_file = "/home/zhihua/work/dora/work/image/3Dimages/lesion__012345678/CupB_Pd25_0_y_-z_x_kvp_30_mgd_4_he_30_pa_60_tvp_15_lesion_2_b3d.rec"

# %% [raw]
# Read in the 3 D data array from a reconstruction file and reshape it to 3D numpy array

# %%
data = np.fromfile(income_file,dtype="float32")
data = data.reshape([d_z,d_y,d_x])

# %% [raw]
# The original slice

# %%
plt.imshow(data[:,d_y/2,:])
